# %%
from spicexplorer.optimization.orchestrator import Circuit_Optimizer_Orchestrator_with_SPICE, Optimizer_Type_Enum
from spicexplorer.logging.logger_setup import setup_loggers

logger = setup_loggers()
# Out:
# 23:20:12 - spicexplorer: [INFO] 🚀 Logger initialized and ready!
# 23:20:12 - spicexplorer: [INFO] 📄 Log file: /home/noorizad/code/SpiceXplorer/examples/folded_cascode/logs/SpiceXplorer_2025-12-21_23-20-12.log
# 23:20:12 - spicexplorer: [INFO] 🔧 spicelib logger set to 50

# %%
optimizer = Circuit_Optimizer_Orchestrator_with_SPICE(
    project_setup_path="project_setup.yaml",
    optimizer_type=Optimizer_Type_Enum.NEVERGRAD_CONSTRAINT,
    verbose=True,
)
# Out:
# 23:20:12 - spicexplorer.designer_tools.domains: [INFO] Initialized OptimizerConfig: TwoPointsDE, type=nevergrad, budget=10, random_seed=48
# 23:20:12 - spicexplorer.designer_tools.domains: [WARNING] No lin_variable_bounds provided; using default [0.0, 1.0].
# 23:20:12 - spicexplorer.designer_tools.domains: [WARNING] No log_variable_bounds provided; using default [0.0, 1.0].
# 23:20:12 - spicexplorer.designer_tools.domains: [WARNING] No loss_function_config provided; using default values.
# 23:20:12 - spicexplorer.designer_tools.domains: [INFO] 	Number of target specs: 3
# 23:20:12 - spicexplorer.designer_tools.domains: [INFO] 		- TargetSpec(name=ugf, target=200e6, range=1.00e+08 tolerance=10000000.0, goal=exact, sim_type=ac, enable=True, error_type=relative-sigmoid, weight=100.0, enable=True, description=Unitiy gain frequency)
# 23:20:12 - spicexplorer.designer_tools.domains: [INFO] 		- TargetSpec(name=dcgain, target=35, range=1.00e+02 tolerance=5, goal=exceed, sim_type=ac, enable=True, error_type=relative-sigmoid, weight=100.0, enable=True, description=gain in dB at DC)
# 23:20:12 - spicexplorer.designer_tools.domains: [INFO] 		- TargetSpec(name=pm, target=70, range=4.50e+01 tolerance=30, goal=exact, sim_type=ac, enable=True, error_type=relative-sigmoid, weight=100.0, enable=True, description=phase margin)
# 23:20:12 - spicexplorer.designer_tools.domains: [INFO] Project 'FOLDED-CASCODE-OTA' initialized with simulator 'ngspice'
# 23:20:12 - spicexplorer.designer_tools.domains: [INFO] 	Workspace root: /home/noorizad/code/SpiceXplorer/examples/folded_cascode
# 23:20:12 - spicexplorer.designer_tools.domains: [INFO] 	Netlist path: testbench.spice
# 23:20:12 - spicexplorer.designer_tools.domains: [INFO] 	Output directory: sizing/spice_out
# 23:20:12 - spicexplorer.designer_tools.domains: [INFO] Resolving ranges for param 'x_dut_nfet_input_w'
# 23:20:12 - spicexplorer.designer_tools.domains: [INFO] Resolving ranges for param 'x_dut_nfet_input_l'
# 23:20:12 - spicexplorer.designer_tools.domains: [INFO] Resolving ranges for param 'x_dut_nfet_mirror_w'
# 23:20:12 - spicexplorer.designer_tools.domains: [INFO] Resolving ranges for param 'x_dut_nfet_mirror_l'
# 23:20:12 - spicexplorer.designer_tools.domains: [INFO] Resolving ranges for param 'x_dut_pfet_load_w'
# 23:20:12 - spicexplorer.designer_tools.domains: [INFO] Resolving ranges for param 'x_dut_pfet_load_l'
# 23:20:12 - spicexplorer.designer_tools.domains: [INFO] ✅ Project setup successfully created
# 23:20:12 - spicexplorer.spice_engine.spicelib: [WARNING] ⚠️ Output directory already exists, re-creating: /home/noorizad/code/SpiceXplorer/examples/folded_cascode/sizing/spice_out
# 23:20:12 - spicexplorer.spice_engine.spicelib: [INFO] --------------------------------------------------
# 23:20:12 - spicexplorer.spice_engine.spicelib: [INFO] 🚀 Spicelib_Wrapper initialized successfully!
# 23:20:12 - spicexplorer.spice_engine.spicelib: [INFO] 	📝 Project: FOLDED-CASCODE-OTA
# 23:20:12 - spicexplorer.spice_engine.spicelib: [INFO] 	📜 Schematic: testbench
# 23:20:12 - spicexplorer.spice_engine.spicelib: [INFO] 	📂 Output Folder: /home/noorizad/code/SpiceXplorer/examples/folded_cascode/sizing/spice_out
# 23:20:12 - spicexplorer.spice_engine.spicelib: [INFO] --------------------------------------------------
# 23:20:12 - spicexplorer.spice_engine.spicelib: [INFO] Using ngspice from ['ngspice']
# 23:20:12 - spicexplorer.spice_engine.spicelib: [INFO] 📊 --- Circuit Information ---
# 23:20:12 - spicexplorer.spice_engine.spicelib: [INFO] 🔗 Nodes in the netlist: ['vdd', 'GND', 'out', 'vin+', 'vin-', 'ib']
# 23:20:12 - spicexplorer.spice_engine.spicelib: [INFO] Testbench parameters: [('CL', '5p'), ('IB', '34u'), ('L_1', '2u'), ('L_2', '2u'), ('L_3', '2.5u'), ('L_4', '2u'), ('L_5', '4.5u'), ('L_6', '3u'), ('L_7', '3u'), ('NG_1', '8'), ('NG_2', '11'), ('NG_3', '5'), ('NG_4', '8'), ('NG_5', '19'), ('NG_6', '5'), ('NG_7', '5'), ('TEMP', '27'), ('VB1', '1.225'), ('VB2', '1.275'), ('VCM', '900m'), ('VDD', '1.8'), ('W_1', '72u'), ('W_2', '106.5u'), ('W_3', '44u'), ('W_4', '78u'), ('W_5', '183u'), ('W_6', '50u'), ('W_7', '50u')]
# 23:20:12 - spicexplorer.spice_engine.spicelib: [WARNING] ⚠️ No DUT parameters found!
# 23:20:12 - spicexplorer.spice_engine.spicelib: [INFO] ✅ --- Circuit info printed successfully --- 🎉

# %%
optimizer.run_sanity_on_spicelib_wrapper()
# Out:
# 23:29:15 - spicexplorer.spice_engine.spicelib: [INFO] 📂 Creating dedicated sanity check folder...
# 23:29:15 - spicexplorer.spice_engine.spicelib: [INFO] 🧪 Running sanity check simulation...
# Sun Dec 21 23:29:15 2025 info: RunTask #2:: Starting simulation 2: /home/noorizad/code/SpiceXplorer/examples/folded_cascode/sizing/spice_out/sanity_check/FOLDED-CASCODE-OTA_sanity.spice
# 23:29:15 - spicexplorer.spice_engine.spicelib: [INFO] simulator log: /home/noorizad/code/SpiceXplorer/examples/folded_cascode/sizing/spice_out/sanity_check/FOLDED-CASCODE-OTA_sanity.log
# 23:29:15 - spicexplorer.spice_engine.spicelib: [INFO] simulator RAW: /home/noorizad/code/SpiceXplorer/examples/folded_cascode/sizing/spice_out/sanity_check/FOLDED-CASCODE-OTA_sanity.raw
# 23:29:15 - spicexplorer.spice_engine.spicelib: [INFO] 🔎 Verifying simulation results...
# 23:29:15 - spicexplorer.spice_engine.spicelib: [INFO] ✅ Sanity check passed 🎉
# Sun Dec 21 23:29:15 2025 info: RunTask #2:Simulation Successful. Time elapsed: 00.0765 secs
#
# Sun Dec 21 23:29:15 2025 info: RunTask #2:Simulation Finished. Calling...dummy_callback(rawfile, logfile)
#
# Sun Dec 21 23:29:15 2025 info: RunTask #2:Simulation Callback Finished. Time elapsed: 00.0000 secs
# True
