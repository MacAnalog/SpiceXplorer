# %%
from spicexplorer.optimization      import Circuit_Optimizer_Orchestrator_with_SPICE
from spicexplorer.viz               import Optimization_Log_Visualizer
from spicexplorer.logging.logger_setup               import setup_loggers_with_spicelib_suppression as setup_loggers

from pathlib import Path

logger = setup_loggers()
logger.info("Spicelib_Wrapper imported successfully.")
# Out:
# 15:26:03 - spicexplorer: [INFO] 🚀 Logger initialized!
# 15:26:03 - spicexplorer: [INFO] 📄 Log file: /home/noorizad/code/SpiceXplorer/examples/OTA/5t-ota/ihp-sg13g2/sizing/logs/SpiceXplorer_2026-02-03_15-26-03.log
# 15:26:03 - spicexplorer: [INFO] 👀 TQDM and Errors will still show in console (stderr).
# 15:26:03 - spicexplorer: [INFO] 🔇 Standard outputs and SPICE logs are redirected to file (stdout).
# 15:26:03 - spicexplorer: [INFO] Spicelib_Wrapper imported successfully.

# %%
path_to_checkpoint = Path("./checkpoints/LHSSearch_2000.json")
viz = Optimization_Log_Visualizer.load_checkpoint(path_to_checkpoint=path_to_checkpoint)
# Out:
# 15:26:03 - spicexplorer.viz.plotting: [INFO] ✅ Checkpoint loaded successfully from checkpoints/LHSSearch_2000.json

# %%
viz.list_available_params()
# Out:
# ['x_dut_nfet_input_w',
#  'x_dut_nfet_input_l',
#  'x_dut_nfet_mirror_w',
#  'x_dut_nfet_mirror_l',
#  'x_dut_nfet_mirror_ref_w',
#  'x_dut_nfet_mirror_ref_l',
#  'x_dut_pfet_load_w',
#  'x_dut_pfet_load_l']

# %%
viz.list_available_metrics()
# Out:
# ['ugf', 'dcgain', 'pm', 'v(inoise_total)', 'tsettle']

# %%
viz.plot_design_space_exploration(param_x="x_dut_nfet_input_w", param_y="x_dut_nfet_mirror_w", show=True)
# Out:
# (array([5.40205495e-06, 4.67323955e-06, 2.67720805e-06, ...,
#         3.52599165e-06, 6.75923967e-06, 5.38144072e-07], shape=(2000,)),
#  array([7.89253219e-06, 2.09709038e-06, 9.72380874e-06, ...,
#         5.39345659e-06, 3.85326729e-06, 6.76527834e-07], shape=(2000,)))

# %%
viz.plot_optimization_trace(metric_x="ugf", metric_y="dcgain", show=True)
viz.plot_optimization_trace(metric_x="ugf", metric_y="dcgain", show=True, log_x=True, log_y=False)
viz.plot_optimization_trace(metric_x="ugf", metric_y="dcgain", show=True, log_x=False, log_y=True)
viz.plot_optimization_trace(metric_x="ugf", metric_y="dcgain", show=True, log_x=True, log_y=True)
# Out:
# (array([49598520., 24681150., 44901200., ..., 48550200., 31640920.,
#          5716487.], shape=(2000,)),
#  array([28.14692, 31.92036, 30.18431, ..., 27.77705, 29.63118, 33.69205],
#        shape=(2000,)))

# %%
viz.plot_optimization_trace(metric_x="v(inoise_total)", metric_y="dcgain", show=True, log_x=True, log_y=False)
# Out:
# (array([0.00047568, 0.00080318, 0.0006804 , ..., 0.00069399, 0.00092998,
#         0.00299395], shape=(2000,)),
#  array([28.14692, 31.92036, 30.18431, ..., 27.77705, 29.63118, 33.69205],
#        shape=(2000,)))

# %%
viz.plot_optimization_trace(metric_x="tsettle", metric_y="dcgain", show=True, log_x=True, log_y=False)
# Out:
# (array([1.10489e-07, 1.47553e-07, 1.13928e-07, ..., 1.13048e-07,
#         1.66511e-07, 2.94464e-07], shape=(2000,)),
#  array([28.14692, 31.92036, 30.18431, ..., 27.77705, 29.63118, 33.69205],
#        shape=(2000,)))
